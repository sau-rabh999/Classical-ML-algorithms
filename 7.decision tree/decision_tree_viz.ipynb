# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()
dataset = pd.DataFrame(data=data['data'], columns=data['feature_names'])
dataset
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
#splitting the dataset

from sklearn.model_selection import train_test_split
x = dataset.copy()
y = data['target']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
x_train
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 56        19.210         18.57          125.50     1152.0          0.10530
# 144       10.750         14.97           68.26      355.3          0.07793
# 60        10.170         14.88           64.55      311.9          0.11340
# 6         18.250         19.98          119.60     1040.0          0.09463
# 8         13.000         21.82           87.50      519.8          0.12730
# ..           ...           ...             ...        ...              ...
# 277       18.810         19.98          120.90     1102.0          0.08923
# 9         12.460         24.04           83.97      475.9          0.11860
# 359        9.436         18.32           59.82      278.6          0.10090
# 192        9.720         18.22           60.73      288.1          0.06950
# 559       11.510         23.93           74.52      403.5          0.09261
#
# ...

# %%
x_test
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 512        13.40         20.52           88.64      556.7          0.11060
# 457        13.21         25.25           84.10      537.9          0.08791
# 439        14.02         15.66           89.59      606.5          0.07966
# 298        14.26         18.17           91.22      633.1          0.06576
# 37         13.03         18.42           82.61      523.8          0.08983
# ..           ...           ...             ...        ...              ...
# 100        13.61         24.98           88.05      582.7          0.09488
# 336        12.99         14.23           84.08      514.3          0.09462
# 299        10.51         23.09           66.85      334.2          0.10150
# 347        14.76         14.74           94.87      668.7          0.08875
# 502        12.54         16.32           81.25      476.3          0.11580
#
# ...

# %%
#training the decision tree model on the training set

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
#fetching parameters

clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
#relevant parameters that define the approach of the tree

#criterion : {gini, entropy}
#splitter : {best, random} (best : choose the better of the 2 criteria, random : pick any one)
#max_features : use a fix no. of features out of all
#random_state : will result in the same tree
#class_weight : one of the classes might be imp than the other
#ccp_alpha : complexity parameter used for minimal-cost complexity pruning. Subtree with the lasgest  cost complexity smaller
#            than ccp alpha will be chosen

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 64,   3],
#        [ 11, 110]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.925531914893617

# %%
print(classification_report(y_test, y_pred, target_names=['malignant', 'benign']))
# Out:
#               precision    recall  f1-score   support
#
#    malignant       0.85      0.96      0.90        67
#       benign       0.97      0.91      0.94       121
#
#     accuracy                           0.93       188
#    macro avg       0.91      0.93      0.92       188
# weighted avg       0.93      0.93      0.93       188

# %%
#fetching all the features

feature_names = x.columns
feature_names
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
#fetch the imp of all these features and print in descending order

feature_imp = pd.DataFrame(clf.feature_importances_, index=feature_names).sort_values(0, ascending=False)
feature_imp
# Out:
#                                 0
# worst concave points     0.728223
# worst area               0.089566
# area error               0.054751
# fractal dimension error  0.024340
# worst texture            0.020623
# mean symmetry            0.018842
# smoothness error         0.015464
# worst symmetry           0.014845
# mean concavity           0.013025
# mean perimeter           0.011043
# worst perimeter          0.009278
# worst compactness        0.000000
# symmetry error           0.000000
# worst smoothness         0.000000
# worst concavity          0.000000
# worst radius             0.000000
# mean radius              0.000000
# compactness error        0.000000
# concave points error     0.000000
# concavity error          0.000000
# mean texture             0.000000
# perimeter error          0.000000
# texture error            0.000000
# radius error             0.000000
# mean fractal dimension   0.000000
# mean concave points      0.000000
# ...

# %%
#fetch all the features with weigths>0

features = list(feature_imp[feature_imp[0]>0].index)
features
# Out:
# ['worst concave points',
#  'worst area',
#  'area error',
#  'fractal dimension error',
#  'worst texture',
#  'mean symmetry',
#  'smoothness error',
#  'worst symmetry',
#  'mean concavity',
#  'mean perimeter',
#  'worst perimeter']

# %%
feature_imp.head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf,
                  feature_names = feature_names,
                  class_names = {0:'Malignant', 1:"Benign"},
                  filled=True,
                  fontsize=12
                  )
